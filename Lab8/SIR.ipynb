# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint, solve_ivp
from matplotlib.pyplot import figure
sp.init_printing()
plt.rcParams.update({'font.size': 22})

# %%
beta = sp.Symbol("beta", real = True)
S = sp.Function("S")
S0 = sp.Symbol("S0")
t = sp.Symbol("t")
I = sp.Symbol("I")

# %% [markdown]
# $$\frac{dS}{dt} = - \frac{\beta SI}{N}$$
# $$\frac{dI}{dt} = \frac{\beta SI}{N} - \gamma I$$
# $$\frac{dR}{dt} = \gamma I$$
# Start: $S(0) + I(0) + R(0) = N = const$
#
# S = susceptible, I - infected, R - recovered

# %%
N = 10000
S_0 = 9999
I_0 = N - S_0
R_0 = 0

# %%
def SIR(y, t, N, beta, gamma):
  S, I, R = y
  SS = -beta*S*I/N
  II = beta*S*I/N - gamma*I
  RR = gamma*I
  return SS, II, RR

# %%
figure(figsize=(8, 6), dpi=80)
b = 0.5
g = 0.25
t = np.linspace(0,60,100)
y_0 = S_0, I_0, R_0
res = odeint(SIR, y_0, t, (N, b, g))
plt.plot(t, res)
# Out:
# [<matplotlib.lines.Line2D at 0x7f62e0c02a60>,
#  <matplotlib.lines.Line2D at 0x7f62e0c02bb0>,
#  <matplotlib.lines.Line2D at 0x7f62e0c02c70>]
